# %% [markdown]
# # Library Visualizations
# ##### Data visualizations of print books in the University of Edinburgh's library
#
# * **Funding:** Edinburgh Futures Institute (EFI)
# * **Data Source:** Library and University Collections (L&UC), OCLC MARC Data for Print Books
# * **Project Dates:** 17 June 2019 - 27 July 2019
# * **Author:** Lucy Havens

# %% [markdown]
# #### This notebook creates a dataframe of library metadata (in MARC format) and then exports a .csv file of the metadata
#
# Load relevant libraries

# %%
import csv
import pandas as pd
import re

# %% [markdown]
# Load .mrc data as a .json files (exported using MarcEdit's OpenRefine Export feature)

# %%
# from: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_json.html
#   when typ == 'frame', allowed orients are {'split','records','index', 'columns','values', 'table'}
#   when typ == 'series', allowed orients are {'split','records','index'}

marc_series0 = pd.read_json('Data/ZIP_FILE2/BatchOf5/JSON/msplit00000000.json', typ='series', orient='index')
marc_series1 = pd.read_json('Data/ZIP_FILE2/BatchOf5/JSON/msplit00000001.json', typ='series', orient='index')
marc_series2 = pd.read_json('Data/ZIP_FILE2/BatchOf5/JSON/msplit00000002.json', typ='series', orient='index')
marc_series3 = pd.read_json('Data/ZIP_FILE2/BatchOf5/JSON/msplit00000003.json', typ='series', orient='index')
marc_series4 = pd.read_json('Data/ZIP_FILE2/BatchOf5/JSON/msplit00000004.json', typ='series', orient='index')

series_list = [marc_series0, marc_series1, marc_series2, marc_series3, marc_series4]

# for elem in marc_series:
#     for subelem in elem:
#         print(subelem)
#         print()

# %% [markdown]
# Each row in the .csv file should correspond with a single "RecordNumber" value.
#
# Column names in the .csv file should correspond with "Tag" + subfield ("$x" in "Content") combinations.

# %%
# FOR ALL MARC DATA:
#   Extract column names from a list of pandas series created from JSON files of MARC data 
#   Create list of indeces based on the number of unique RecordNumbers (book) in each JSON file


def columnsFromJSON(json_series_list):
    csv_cols = []
    csv_indeces_lists = []
    i = 0
    for json_series in json_series_list:
        csv_indeces = []
        for elem in json_series:
            for subelem in elem:
                record_no = subelem['RecordNumber']
                if (record_no not in csv_indeces) and (record_no != ''):
                    csv_indeces.append(record_no)
                # Construct column names
                tag = subelem['Tag']
                # In MARC, subfields are indicated with a dollar sign and lower case letter
                subfields_list = re.findall("\$\w{1}",subelem['Content'])
                for subfield in subfields_list:
                    marc_field = tag+subfield
                    if marc_field not in csv_cols:
                        csv_cols += [marc_field]
            
        csv_indeces_lists += [csv_indeces]
    
    return [csv_cols,csv_indeces_lists]


[column_names,row_indeces] = columnsFromJSON(series_list)
total_rows = len(row_indeces[0]) + len(row_indeces[1]) + len(row_indeces[2]) + len(row_indeces[3]) + len(row_indeces[4])

print("Total Columns:", len(column_names))
print("Total Records:", total_rows)
# Out:
# Total Columns: 582
# Total Records: 5000

# %%
# FOR SUBSET OF MARC DATA:
#   Metadata to export in .csv file for visualization:

marc_tags_fields = ['020$a', '020$c', '041$a', '043$a', '045', '050$a', '072$a', '082$a',
       '100$a', '100$e', '130$a', '130$l', '240$a', '240$f', '240$l', '245$a',
       '245$b', '245$c', '260$a', '260$b', '260$c', '264$a', '264$b', '264$c',
       '300$a', '336$a', '336$b', '600$a', '600$c', '600$d', '600$t', '600$x',
       '600$z', '630$a', '630$l', '630$v', '630$x', '650$a', '650$x', '650$y',
       '650$z', '651$a', '651$x', '651$y', '651$z', '655$a', '655$a.1',
       '655$y']

marc_names = ['isbn', 'isbn1', 'text_language', 'geographic_area_code',
       'time_period_of_content', 'loc_call_no', 'subject_cat_code', 'dewey_no',
       'personal_name', 'relator', 'uniform_title', 'real_world_obj_URI',
       'uniform_title1', 'date_of_work', 'real_world_obj_URI1', 'title',
       'title_cont', 'stat_of_resp', 'publ_place', 'publisher', 'publ_date',
       'publ_place1', 'publisher1', 'publ_date1', 'physical_desc',
       'content_type_term', 'content_type_code', 'personal_name1',
       'titles_words_assoc_w_name', 'dates_assoc_w_name', 'title1',
       'general_subdivision', 'geo_subdivision', 'uniform_title1',
       'real_world_obj_URI2', 'form_subdivision', 'general_subdivision1',
       'topic_or_geo', 'general_subdivision2', 'chrono_subdivision',
       'geo_subdivision1', 'geo_name', 'general_subdivision3',
       'chrono_subdivision1', 'geo_subdivision2', 'genre_form_focus',
       'genre_form_focus1', 'chrono_subdivision2']

field_name_dict = dict(zip(marc_tags_fields,marc_names))
# field_name_dict

# %%
# INPUT: pandas series read from a JSON file, a MARC field, and a list of record numbers
# OUTPUT: list of column values (one per record number) for the inputted MARC field (col_name)
def colValuesFromJSON(json_series, col_name, csv_index):
    col_values = {}
    col_values = col_values.fromkeys(csv_index,"Unknown")  # 1000
    for elem in json_series:
        for subelem in elem:
            record_no = subelem['RecordNumber']
            
            # Ignore empty items in json_series
            if (record_no != ''):

                tag = subelem['Tag']

                # Determine whether the json_series subelement has relevant content for the inputted column name
                if tag in col_name:
                    
                    # If the column name is a MARC subfield, extract relevant subcontent...
                    content = subelem['Content']
                    if ('$' in col_name) and ('$' in content):
                        # Obtain the subfield
                        subfield = col_name[-1]
                        # Find the content data associated with the subfield
                        subcontent = re.findall("\$"+subfield+"{1}[^$]+",content)  # returns a list
                        subfield = '$' + subfield
                        for val in subcontent:
                            col_values[record_no] = val.replace(subfield,'')
                    # ...otherwise, add all content
                    else:
                        col_values[record_no] = subelem['Content']

    return list(col_values.values())

# %% [markdown]
# Extract MARC data from the json series as is relevant to the subset of data of interest ("marc_tags_fields"), adding the data to a DataFrame one column (MARC field) at a time.

# %%
df = pd.DataFrame()
for tag_field in marc_tags_fields:
    i = 0
    maxI = len(series_list)
    col_vals = []
    while i < maxI:
        col_vals += colValuesFromJSON(series_list[i],tag_field,row_indeces[i])
        i+= 1
    
    col_name = field_name_dict[tag_field]  # obtain the MARC field name from the MARC field code
    df[col_name] = col_vals
df
# Out:
#                                 isbn    isbn1 text_language  \
# 0                            Unknown  Unknown        grclat
# 1                            Unknown  Unknown       Unknown
# 2               9781403976277 (hbk.)  Unknown       Unknown
# 3                      9780230007895  Unknown       Unknown
# 4                         1403996237  Unknown       Unknown
# 5                         1842143050  Unknown       Unknown
# 6                            Unknown  Unknown           lat
# 7                            Unknown  Unknown       Unknown
# 8                            Unknown  Unknown       Unknown
# 9               9781842773215 (pbk.)  Unknown           eng
# 10    0822334429 (pbk. : alk. paper)  Unknown       Unknown
# 11                           Unknown  Unknown       Unknown
# 12                           Unknown  Unknown           lat
# 13                           Unknown  Unknown       Unknown
# 14                           Unknown  Unknown       Unknown
# 15                     9784061860223  Unknown           eng
# 16                           Unknown  Unknown           lat
# 17                        0415448727  Unknown       Unknown
# 18                     9784061860193  Unknown           eng
# 19                           Unknown  Unknown       Unknown
# 20                           Unknown  Unknown       Unknown
# 21                     9784770023292  Unknown        engjpn
# 22              9780199296019 (hbk.)  Unknown       Unknown
# 23                           Unknown  Unknown       Unknown
# 24                     9784906319770  Unknown           jpn
# 25                     9784634290600  Unknown       Unknown
# 26                           Unknown  Unknown       Unknown
# 27                           Unknown     Y480       Unknown
# 28                           Unknown     Y480       Unknown
# 29                           Unknown  Unknown       Unknown
# ...                              ...      ...           ...
# 4970                         Unknown  Unknown       Unknown
# 4971                      9076998434  Unknown       Unknown
# 4972                      0691117640  Unknown       Unknown
# 4973                         Unknown  Unknown       Unknown
# 4974  0415914833 (pbk. : alk. paper)  Unknown       Unknown
# 4975                      0140447997  Unknown           eng
# 4976                      0872291197  Unknown       Unknown
# 4977            9781403964663 (hbk.)  Unknown           chi
# 4978                         Unknown  Unknown       Unknown
# 4979                      1841582891  Unknown       Unknown
# 4980                      1899874461  Unknown       Unknown
# 4981                         Unknown  Unknown       Unknown
# 4982                      1402071132  Unknown       Unknown
# 4983                      0199267669  Unknown       Unknown
# 4984               0199267278 (pbk.)  Unknown       Unknown
# 4985                      0262041707  Unknown       Unknown
# 4986                         Unknown  Unknown       Unknown
# 4987                         Unknown  Unknown       Unknown
# 4988                         Unknown  Unknown       Unknown
# 4989                         Unknown  Unknown       Unknown
# 4990                      2220020444  Unknown           gre
# 4991                         Unknown  Unknown       Unknown
# 4992                         Unknown  Unknown       Unknown
# 4993                         Unknown  Unknown       Unknown
# 4994                         Unknown  Unknown       Unknown
# 4995                         Unknown  Unknown       Unknown
# 4996                      9953450501  Unknown       Unknown
# 4997                         Unknown  Unknown       Unknown
# 4998                         Unknown  Unknown       Unknown
# 4999                      880903760X  Unknown       Unknown
#
#      geographic_area_code time_period_of_content           loc_call_no  \
# 0                 Unknown                Unknown                PA3872
# 1                 Unknown                Unknown               Unknown
# 2                 n-us---                Unknown             HB119.F84
# 3                 e-it---                Unknown             HB109.M63
# 4                 e-uk---                Unknown             HB103.K47
# 5                 Unknown                Unknown                 RG136
# 6                 Unknown                Unknown                PA3443
# 7                 Unknown                Unknown               Unknown
# 8                 Unknown                Unknown             PA3872.Z4
# 9                 n-us---                Unknown                 HB501
# 10                Unknown                Unknown                  HN13
# 11                Unknown                Unknown               Unknown
# 12                Unknown                Unknown             PA4035.N5
# 13                Unknown                Unknown               Unknown
# 14                Unknown                Unknown               Unknown
# 15                Unknown                Unknown              PL852.O8
# 16                Unknown                Unknown             PA4035.N5
# 17                n-us---                Unknown            JZ1480.A54
# 18                Unknown                Unknown               Unknown
# 19                Unknown                Unknown               Unknown
# 20                a-ja---                Unknown             PN1978.J3
# 21                a-ja---                Unknown              PL787.T3
# 22                e------                Unknown               KJC1083
# 23                Unknown                Unknown             PA3872.Z4
# 24                Unknown                Unknown                KJE947
# 25                a-ja---                Unknown                 DS835
# 26                a-ja---                Unknown         DS894.59.A352
# 27                a-ja---                Unknown         DS894.79.O372
# 28                a-ja---                Unknown         DS894.39.F832
# 29                Unknown                Unknown         DS894.39.M592
# ...                   ...                    ...                   ...
# 4970              Unknown                Unknown             SDA 16384
# 4971              Unknown                Unknown                  S590
# 4972              as-----                Unknown       BQ924 .S77 2004
# 4973              a-ph---                Unknown               Unknown
# 4974              a-ii---                Unknown             BQ1133.W6
# 4975              Unknown                Unknown        BL1140.4.B4342
# 4976              a-cc---                Unknown                 T14.5
# 4977              a-ja---                Unknown                PL2302
# 4978              Unknown                Unknown             K14131971
# 4979              e-uk-st                Unknown               Unknown
# 4980              Unknown                Unknown               Unknown
# 4981              Unknown                $bd1803               Unknown
# 4982              Unknown                Unknown              TK7874.6
# 4983              n-us---                Unknown               HC79.P6
# 4984              e------                Unknown       JC479 .N49 2004
# 4985              Unknown                Unknown  N6834.5.T45 K37 1999
# 4986              Unknown                Unknown               Unknown
# 4987              Unknown                Unknown               Unknown
# 4988              Unknown                Unknown               Unknown
# 4989              Unknown                Unknown               Unknown
# 4990              Unknown                Unknown    BS2775.2 .V32 1976
# 4991              Unknown                Unknown               Unknown
# 4992              Unknown                Unknown               Unknown
# 4993              Unknown                Unknown               Unknown
# 4994              Unknown                Unknown               Unknown
# 4995              Unknown                Unknown               Unknown
# 4996              Unknown                Unknown               DS119.7
# 4997              Unknown                Unknown               Unknown
# 4998              Unknown                Unknown               Unknown
# 4999              Unknown                Unknown             ND623.B92
#
#      subject_cat_code     dewey_no                       personal_name  \
# 0             Unknown      Unknown                         Apollonius,
# 1             Unknown      Unknown                      Lamond, Peter,
# 2             Unknown      Unknown                  Ebenstein, Alan O.
# 3             Unknown            B                  Szenberg, Michael.
# 4             Unknown      330.156                     Davidson, Paul,
# 5             Unknown       613.94                             Unknown
# 6             Unknown      Unknown     Schneidewin, Friedrich Wilhelm,
# 7             Unknown      Unknown                     King, Nicholas,
# 8             Unknown      Unknown                    Rzach, Aloisius.
# 9             Unknown      Unknown                        Amin, Samir.
# 10            Unknown        303.4      Wallerstein, Immanuel Maurice,
# 11            Unknown      Unknown                    Leyne, Jeremiah.
# 12            Unknown      Unknown                            Nicanor,
# 13            Unknown      Unknown                     Little, Joseph.
# 14            Unknown      Unknown                        Locke, John,
# 15            Unknown    895.6/3/5                   Hoshi, Shin'ichi,
# 16            Unknown      Unknown                            Nicanor,
# 17            Unknown     327.7304                         Toje, Asle.
# 18            Unknown    895.6/3/5                    Atōda, Takashi,
# 19            Unknown      Unknown              Loy, Martin Augustine,
# 20            Unknown      Unknown                  Miyake, Shūtarō,
# 21            Unknown      Unknown                             Unknown
# 22            Unknown      Unknown                 Bar, Christian von,
# 23            Unknown      Unknown                      Händel, Paul,
# 24            Unknown      Unknown                 Edward, David A. O.
# 25            Unknown      Unknown                             Unknown
# 26            Unknown      Unknown                             Unknown
# 27            Unknown      Unknown                             Unknown
# 28            Unknown      Unknown                             Unknown
# 29            Unknown      Unknown                             Unknown
# ...               ...          ...                                 ...
# 4970          Unknown      Unknown                 Van de Vate, Nancy.
# 4971          Unknown      Unknown                             Unknown
# 4972          Unknown      Unknown                       Strong, John,
# 4973          Unknown      Unknown              Tweeddale, Arthur Hay,
# 4974          Unknown    294.3/082                    Young, Serinity.
# 4975          Unknown     294.5925                             Unknown
# 4976          Unknown      Unknown                    Bray, Francesca.
# 4977          Unknown      Unknown            Keaveney, Christopher T.
# 4978          Unknown      Unknown                             Unknown
# 4979          Unknown   338.709411                     Foreman, Carol.
# 4980          Unknown  133.4309411                      Miller, Joyce,
# 4981          Unknown      Unknown              Beethoven, Ludwig van,
# 4982          Unknown     621.3815                    Chinnery, David.
# 4983          Unknown    362.57094                   Alesina, Alberto.
# 4984          Unknown      Unknown                             Unknown
# 4985          Unknown       700.92                             Unknown
# 4986          Unknown      Unknown                    Berdal, Mats R.,
# 4987          Unknown      Unknown                Milne, Katrinna E.C.
# 4988          Unknown      Unknown             Bach, Johann Sebastian,
# 4989          Unknown      Unknown                Miners, Christine V.
# 4990          Unknown     227.8706                    Vanhoye, Albert.
# 4991          Unknown      Unknown                  Fleischer, Tsippi.
# 4992          Unknown      Unknown               Schofield, Fiammetta.
# 4993          Unknown      Unknown  Schreber, Johann Christian Daniel,
# 4994          Unknown      Unknown                        Ball, James,
# 4995          Unknown      Unknown                     Boulez, Pierre,
# 4996          Unknown      Unknown                             Unknown
# 4997          Unknown      Unknown              Beethoven, Ludwig van,
# 4998          Unknown      Unknown                    Haworth, Muriel.
# 4999          Unknown      Unknown                   Falletti, Franca.
#
#          relator         ...                general_subdivision2  \
# 0        Unknown         ...                             Unknown
# 1        Unknown         ...                             Unknown
# 2        Unknown         ...                             Unknown
# 3        Unknown         ...                             Unknown
# 4        Unknown         ...                             Unknown
# 5        Unknown         ...                             Unknown
# 6        Unknown         ...                             Unknown
# 7        Unknown         ...                             Unknown
# 8        Unknown         ...                             Unknown
# 9        Unknown         ...                  Political aspects.
# 10       Unknown         ...                     Social aspects.
# 11       Unknown         ...                             Unknown
# 12       Unknown         ...              History and criticism.
# 13       Unknown         ...                             Unknown
# 14       Unknown         ...                             Unknown
# 15       Unknown         ...                             Unknown
# 16       Unknown         ...                             Unknown
# 17       Unknown         ...          International cooperation.
# 18       Unknown         ...                             Unknown
# 19       Unknown         ...                             Unknown
# 20       Unknown         ...                             Unknown
# 21       Unknown         ...                             Unknown
# 22       Unknown         ...                             Unknown
# 23       Unknown         ...                             Unknown
# 24       Unknown         ...                   Yoroppa kyodotai.
# 25       Unknown         ...                             Unknown
# 26       Unknown         ...                             Unknown
# 27       Unknown         ...                             Unknown
# 28       Unknown         ...                             Unknown
# 29       Unknown         ...                             Unknown
# ...          ...         ...                                 ...
# 4970     Unknown         ...                             Unknown
# 4971     Unknown         ...                             Unknown
# 4972     Unknown         ...                            History.
# 4973     Unknown         ...                             Unknown
# 4974     Unknown         ...                             Unknown
# 4975     Unknown         ...                             Unknown
# 4976     Unknown         ...                      Social aspects
# 4977     Unknown         ...              History and criticism.
# 4978     Unknown         ...                             Unknown
# 4979     Unknown         ...                            History.
# 4980     Unknown         ...                            History.
# 4981     Unknown         ...                             Unknown
# 4982     Unknown         ...                             Unknown
# 4983     Unknown         ...                   Government policy
# 4984     Unknown         ...                             Unknown
# 4985     Unknown         ...                             Unknown
# 4986     Unknown         ...                             Unknown
# 4987     Unknown         ...                             Unknown
# 4988   composer.         ...                             Unknown
# 4989     Unknown         ...                             Unknown
# 4990     Unknown         ...                             Unknown
# 4991     Unknown         ...                             Unknown
# 4992     Unknown         ...                             Unknown
# 4993     Unknown         ...                             Unknown
# 4994     Unknown         ...                             Unknown
# 4995  conductor.         ...                             Unknown
# 4996     Unknown         ...                             Unknown
# 4997     Unknown         ...                             Unknown
# 4998     Unknown         ...                             Unknown
# 4999     Unknown         ...                             Unknown
#
#            chrono_subdivision geo_subdivision1                  geo_name  \
# 0                     Unknown          Unknown                   Unknown
# 1                     Unknown          Unknown                   Unknown
# 2                     Unknown    United States                   Unknown
# 3                     Unknown           Italy.                   Unknown
# 4                     Unknown   Great Britain.                   Unknown
# 5                     Unknown          Unknown                   Unknown
# 6                     Unknown          Greece.                   Unknown
# 7                     Unknown          Unknown                   Unknown
# 8                     Unknown          Unknown                   Unknown
# 9                     Unknown          Unknown             United States
# 10                    Unknown          Unknown                   Unknown
# 11                    Unknown          Unknown                   Unknown
# 12                    Unknown          Unknown                   Unknown
# 13                    Unknown          Unknown                   Unknown
# 14                    Unknown          Unknown                   Unknown
# 15                    Unknown          Unknown                   Unknown
# 16                    Unknown          Unknown                   Unknown
# 17                    Unknown          Unknown  European Union countries
# 18                    Unknown          Unknown                   Unknown
# 19                    Unknown          Unknown                   Unknown
# 20                    Unknown           Japan.                   Unknown
# 21    Heian period, 794-1185.          Unknown                   Unknown
# 22                    Unknown          Europe.                   Unknown
# 23                    Unknown          Unknown                   Unknown
# 24                    Unknown          Unknown                   Unknown
# 25                    Unknown    Yamagata-ken.      Yamagata-ken (Japan)
# 26                    Unknown        Aichi-ken         Aichi-ken (Japan)
# 27                    Unknown      Okayama-ken       Okayama-ken (Japan)
# 28                    Unknown          Unknown     Fukushima-ken (Japan)
# 29                    Unknown      Miyagi-ken.        Miyagi-ken (Japan)
# ...                       ...              ...                       ...
# 4970                  Unknown          Unknown                   Unknown
# 4971                  Unknown          Unknown                   Unknown
# 4972                  Unknown   Southeast Asia                   Unknown
# 4973                  Unknown     Philippines.                   Unknown
# 4974                  Unknown           India.                   Unknown
# 4975                  Unknown          Unknown                   Unknown
# 4976                  Unknown           China.                     China
# 4977             20th century          Unknown                   Unknown
# 4978                  Unknown          Unknown                   Unknown
# 4979                  Unknown         Scotland                   Unknown
# 4980                  Unknown         Scotland                   Unknown
# 4981            18th century.          Unknown                   Unknown
# 4982                  Unknown          Unknown                   Unknown
# 4983                  Unknown   United States.                   Unknown
# 4984                  Unknown           Europe                   Unknown
# 4985                  Unknown  Czechoslovakia.                   Unknown
# 4986                  Unknown          Unknown                   Unknown
# 4987                  Unknown          Unknown                   Unknown
# 4988                  Unknown          Unknown                   Unknown
# 4989                  Unknown          Unknown                   Unknown
# 4990                  Unknown          Unknown                   Unknown
# 4991                  Unknown          Unknown                   Unknown
# 4992                  Unknown          Unknown                   Unknown
# 4993                  Unknown          Unknown                   Unknown
# 4994                  Unknown          Unknown                   Unknown
# 4995                  Unknown          Unknown                   Unknown
# 4996                    1993-       Palestine.                   Unknown
# 4997                  Unknown          Unknown                   Unknown
# 4998                  Unknown          Unknown                   Unknown
# 4999                  Unknown          Unknown                   Unknown
#
#          general_subdivision3 chrono_subdivision1 geo_subdivision2  \
# 0                     Unknown             Unknown          Unknown
# 1                     Unknown             Unknown          Unknown
# 2                     Unknown             Unknown          Unknown
# 3                     Unknown             Unknown          Unknown
# 4                     Unknown             Unknown          Unknown
# 5                     Unknown             Unknown          Unknown
# 6                     Unknown             Unknown          Unknown
# 7                     Unknown             Unknown          Unknown
# 8                     Unknown             Unknown          Unknown
# 9           Foreign relations               1989-          Unknown
# 10                    Unknown             Unknown          Unknown
# 11                    Unknown             Unknown          Unknown
# 12                    Unknown             Unknown          Unknown
# 13                    Unknown             Unknown          Unknown
# 14                    Unknown             Unknown          Unknown
# 15                    Unknown             Unknown          Unknown
# 16                    Unknown             Unknown          Unknown
# 17          Foreign relations             Unknown   United States.
# 18                    Unknown             Unknown          Unknown
# 19                    Unknown             Unknown          Unknown
# 20                    Unknown             Unknown          Unknown
# 21                    Unknown             Unknown          Unknown
# 22                    Unknown             Unknown          Unknown
# 23                    Unknown             Unknown          Unknown
# 24                    Unknown             Unknown          Unknown
# 25    Description and travel.             Unknown          Unknown
# 26                    Unknown             Unknown          Unknown
# 27                    Unknown             Unknown          Unknown
# 28                   History.             Unknown          Unknown
# 29                    Unknown             Unknown          Unknown
# ...                       ...                 ...              ...
# 4970                  Unknown             Unknown          Unknown
# 4971                  Unknown             Unknown          Unknown
# 4972                  Unknown             Unknown          Unknown
# 4973                  Unknown             Unknown          Unknown
# 4974                  Unknown             Unknown          Unknown
# 4975                  Unknown             Unknown          Unknown
# 4976        Social conditions           960-1644.          Unknown
# 4977                  Unknown             Unknown          Unknown
# 4978                  Unknown             Unknown          Unknown
# 4979                  Unknown             Unknown          Unknown
# 4980                  Unknown             Unknown          Unknown
# 4981                  Unknown             Unknown          Unknown
# 4982                  Unknown             Unknown          Unknown
# 4983                  Unknown             Unknown          Unknown
# 4984                  Unknown             Unknown          Unknown
# 4985                  Unknown             Unknown          Unknown
# 4986                  Unknown             Unknown          Unknown
# 4987                  Unknown             Unknown          Unknown
# 4988                  Unknown             Unknown          Unknown
# 4989                  Unknown             Unknown          Unknown
# 4990                  Unknown             Unknown          Unknown
# 4991                  Unknown             Unknown          Unknown
# 4992                  Unknown             Unknown          Unknown
# 4993                  Unknown             Unknown          Unknown
# 4994                  Unknown             Unknown          Unknown
# 4995                  Unknown             Unknown          Unknown
# 4996                  Unknown             Unknown          Unknown
# 4997                  Unknown             Unknown          Unknown
# 4998                  Unknown             Unknown          Unknown
# 4999                  Unknown             Unknown          Unknown
#
#      genre_form_focus genre_form_focus1 chrono_subdivision2
# 0             Unknown           Unknown             Unknown
# 1             Unknown           Unknown             Unknown
# 2             Unknown           Unknown             Unknown
# 3             Unknown           Unknown             Unknown
# 4             Unknown           Unknown             Unknown
# 5             Unknown           Unknown             Unknown
# 6             Unknown           Unknown             Unknown
# 7             Unknown           Unknown             Unknown
# 8             Unknown           Unknown             Unknown
# 9             Unknown           Unknown             Unknown
# 10            Unknown           Unknown             Unknown
# 11            Unknown           Unknown             Unknown
# 12            Unknown           Unknown             Unknown
# 13            Unknown           Unknown             Unknown
# 14            Unknown           Unknown             Unknown
# 15            Unknown           Unknown             Unknown
# 16            Unknown           Unknown             Unknown
# 17            Unknown           Unknown             Unknown
# 18            Unknown           Unknown             Unknown
# 19            Unknown           Unknown             Unknown
# 20            Unknown           Unknown             Unknown
# 21            Unknown           Unknown             Unknown
# 22            Unknown           Unknown             Unknown
# 23            Unknown           Unknown             Unknown
# 24            Unknown           Unknown             Unknown
# 25            Unknown           Unknown             Unknown
# 26            Unknown           Unknown             Unknown
# 27            Unknown           Unknown             Unknown
# 28            Unknown           Unknown             Unknown
# 29            Unknown           Unknown             Unknown
# ...               ...               ...                 ...
# 4970          Unknown           Unknown             Unknown
# 4971          Unknown           Unknown             Unknown
# 4972          Unknown           Unknown             Unknown
# 4973          Unknown           Unknown             Unknown
# 4974          Unknown           Unknown             Unknown
# 4975          Unknown           Unknown             Unknown
# 4976          Unknown           Unknown             Unknown
# 4977          Unknown           Unknown             Unknown
# 4978          Unknown           Unknown             Unknown
# 4979          Unknown           Unknown             Unknown
# 4980          Unknown           Unknown             Unknown
# 4981          Unknown           Unknown             Unknown
# 4982          Unknown           Unknown             Unknown
# 4983          Unknown           Unknown             Unknown
# 4984          Unknown           Unknown             Unknown
# 4985          Unknown           Unknown             Unknown
# 4986          Unknown           Unknown             Unknown
# 4987          Unknown           Unknown             Unknown
# 4988          Unknown           Unknown             Unknown
# 4989          Unknown           Unknown             Unknown
# 4990          Unknown           Unknown             Unknown
# 4991          Unknown           Unknown             Unknown
# 4992          Unknown           Unknown             Unknown
# 4993          Unknown           Unknown             Unknown
# 4994          Unknown           Unknown             Unknown
# 4995          Unknown           Unknown             Unknown
# 4996          Unknown           Unknown             Unknown
# 4997          Unknown           Unknown             Unknown
# 4998          Unknown           Unknown             Unknown
# 4999          Unknown           Unknown             Unknown
#
# [5000 rows x 47 columns]

# %%
df.shape
# Out:
# (5000, 47)

# %% [markdown]
# Export a CSV file of the DataFrame

# %%
# Out:
# [2]
